# %%
# 필요한 도구 임포트
from sklearn import preprocessing
import pandas as pd

# %%
PATIENT_FILE_PATH = './datasets/indian_liver_patient.csv'
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# 데이터 파일을 pandas dataframe으로 가지고 온다
liver_patients_df = pd.read_csv(PATIENT_FILE_PATH)
liver_patients_df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female          0.70000           0.10000                   187
# 1     62    Male         10.90000           5.50000                   699
# 2     62    Male          7.30000           4.10000                   490
# 3     58    Male          1.00000           0.40000                   182
# 4     72    Male          3.90000           2.00000                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male          0.50000           0.10000                   500
# 579   40    Male          0.60000           0.10000                    98
# 580   52    Male          0.80000           0.20000                   245
# 581   31    Male          1.30000           0.50000                   184
# 582   38    Male          1.00000           0.30000                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18         6.80000
# 1                          64                         100         7.50000
# 2                          60                          68         7.00000
# 3                          14                          20         6.80000
# 4                          27                          59         7.30000
# ..                        ...                         ...             ...
# 578                        20                          34         5.90000
# 579                        35                          31         6.00000
# 580                        48                          49         6.40000
# 581                        29                          32         6.80000
# 582                        21                          24         7.30000
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0    3.30000                     0.90000        1
# 1    3.20000                     0.74000        1
# 2    3.30000                     0.89000        1
# 3    3.40000                     1.00000        1
# 4    2.40000                     0.40000        1
# ..       ...                         ...      ...
# 578  1.60000                     0.37000        2
# 579  3.20000                     1.10000        1
# 580  3.20000                     1.00000        1
# 581  3.40000                     1.00000        1
# 582  4.40000                     1.50000        2
#
# [583 rows x 11 columns]

# %%
# Normalization할 열 이름들
features_to_normalize = ['Total_Bilirubin','Direct_Bilirubin', 'Alkaline_Phosphotase', 'Alamine_Aminotransferase']

# %%
scaler = preprocessing.MinMaxScaler()

normalized_data = scaler.fit_transform(liver_patients_df[features_to_normalize])

normalized_df = pd.DataFrame(normalized_data, columns=features_to_normalize)

# %%
normalized_df.describe()
# Out:
#        Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count        583.00000         583.00000             583.00000
# mean           0.03886           0.07072               0.11118
# std            0.08324           0.14329               0.11868
# min            0.00000           0.00000               0.00000
# 25%            0.00536           0.00510               0.05496
# 50%            0.00804           0.01020               0.07084
# 75%            0.02949           0.06122               0.11480
# max            1.00000           1.00000               1.00000
#
#        Alamine_Aminotransferase
# count                 583.00000
# mean                    0.03553
# std                     0.09177
# min                     0.00000
# 25%                     0.00653
# 50%                     0.01256
# 75%                     0.02538
# max                     1.00000
